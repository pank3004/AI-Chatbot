# %%
from langchain_cerebras import ChatCerebras
llm = ChatCerebras(model="llama-3.3-70b")

# %%
llm.invoke("what is the capital of india")
# Out:
# AIMessage(content='The capital of India is New Delhi.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 41, 'total_tokens': 50, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'llama-3.3-70b', 'system_fingerprint': 'fp_2bc09d9bd1ce5f6aa987', 'id': 'chatcmpl-41adbbe0-71a2-4428-93e2-925278b4da99', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bb60c-7ed6-7c53-ba7a-c05f1e767c43-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 9, 'total_tokens': 50, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})
